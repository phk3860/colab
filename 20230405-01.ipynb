# %%
#덧샘 +곱샘= 연속(함수)

# %%
a = []
b = [1, 2, 3]
c = ['Life', 'is', 'too', 'short']
d = [1, 2, 'Life', 'is']
e = [1, 2, ['Life', 'is']]

len(e[2])
# Out:
# 2

# %%
a = [1,2,3]
b = a
a[0] = a

# %%
a.append(4)

# %%
a=[1,2,3]
a.append(4)
a.append(5)
a.append([6.7])
del a[3]
a
# Out:
# [1, 2, 3, 5, [6.7]]

# %%
t1 = ()
t2 = (1,)
t3 = (1, 2, 3)
t4 = 1, 2, 3
t5 = ('a', 'b', ('ab', 'cd'))

# %%
len(t2)
# Out:
# 1

# %%
t1 = ()
t2 = (1)
t3 = (1, 2, 3)
t4 = 1, 2, 3
t5 = ('a', 'b', ('ab', 'cd'))

# %%
len(t2)
# Out:
# 1

# %%
len(t3)
# Out:
# 3

# %%
t4
# Out:
# (1, 2, 3)

# %%
a=1
b=2

# %%
(a,b)=(1,2)  #unpack

# %%
b
# Out:
# 2

# %%
a
# Out:
# 1

# %%
a,b,c=1,2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-dfc132c7dc8e> in <cell line: 1>()
# ----> 1 a,b,c=1,2
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
len(t5)
# Out:
# 3

# %%
t5[:2]
# Out:
# ('a', 'b')

# %%
a='python'
a=a[:3]
a
# Out:
# 'pyt'

# %%
t1 = (1, 2, 'a', 'b')
t1[1:]
# Out:
# (2, 'a', 'b')

# %%
dic = {'name':'pey', 'phone':'010-9999-1234', 'birth': '1118'}

# %%
dic['name']
# Out:
# 'pey'

# %%
dic['phone']
# Out:
# '010-9999-1234'

# %%
a=[10,20,30,40,50]
a[1]
a={'철수':10,'수진':20}
a['철수']
# Out:
# 10

# %%
a=['수진']

# %%
a={1:10,(2,3,4):20}
a[2,3,4]
# Out:
# 20

# %%
a={}
a['asdf']=1
a['qwer']=2
del a['asdf']
a
# Out:
# {'qwer': 2}

# %%
a=3
a>3
# Out:
# False

# %%
5==10
# Out:
# False

# %%
True,False
# Out:
# (True, False)

# %%
3 in [0,1,2,3,]   #값이 있는지 없는지
# Out:
# True

# %%
5 in [0,1,2,3,]   #interable : 반복가능한
# Out:
# False

# %%
type['12']
# Out:
# type['12']

# %%
id='875432-1012345'
birth= id[:6]
remau

# %%
money = True
if money:
  print('택시 타고가라')
else:
  print('걸어가라')
# Out:
# 택시 타고가라

# %%
score=60
if score >=90:
  print('a')
elif score >=80:
  print('b')
elif score >=70:
  print('c')

# %%
for e in[1,2,3]:
  print(e)
# Out:
# 1
# 2
# 3

# %%
for e in[1,2,3,4,5,6,7,8,9]:
  if e % 3==0:
    print(e)
# Out:
# 3
# 6
# 9

# %%
v=0
for e in[1,2,3,4,5,6,7,8,9]:
  v=v+e
v
# Out:
# 45

# %%
m=0
for e in[3,1,6,4,2,5]:
    if m <e:
        m=e
m
# Out:
# 6

# %%
m=0 #최소한의 산수 :1차함수 -직선의 함수 , 수열 -반복문 , 삼각함수, 함수,행렬연산,미분 딥러닝 경사하강법 =프레임워크로 만들어짐짐,
      #행렬 : 넘파이 
for e in[3,1,6,4,2,5]:
    if m <e:
        m=e
m
# Out:
# 6

# %%
a=[1,2,3,4]
b=[] #[2,4,6,8]
for v in a:
    b.append(v*2)
b
# Out:
# [2, 4, 6, 8]

# %%
a=[1,2,3,4]
b=[]
for v in a:
    b.append(v*2+1)
b
# Out:
# [3, 5, 7, 9]

# %%
a=[1,2,3,4]
b=[v*2+1 for v in a] #리스트내포구문
b
# Out:
# [3, 5, 7, 9]

# %%
a=[1,2,3,4]
b=[v*2+3 for v in a] #리스트내포구문
b
# Out:
# [5, 7, 9, 11]

# %%
def func(x):
    return x *2+1
b=list(map(func,a))
b
# Out:
# [3, 5, 7, 9]

# %%
total = 0
for v in range(1,11):
  # 생성함수 =range[1,2,3,4,5,6,7,8,9]:
    total +=v
total
# Out:
# 55

# %%
for v in range(5):
    print(v)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
list(range(5))
# Out:
# [0, 1, 2, 3, 4]

# %%
a=(1,2,3)
list(a)
# Out:
# [1, 2, 3]

# %%
a=[1,2,3]
tuple(a)
# Out:
# (1, 2, 3)

# %%
a=range(5)    #generator : 비동기 프로그레밍
                          #멀티 스레딩
                          #멀티프로세싱 /리스트 비슷한거
a
# Out:
# range(0, 5)

# %%
def func(x):
    return x*2
a=[1,2,3]
b=map(func,a)  #함수제공 map(f,a) 제네레이터를 리스트로 변환
list(b)
# Out:
# [2, 4, 6]

# %% [markdown]
# 함수

# %%
def func(a,b,c):
    d=b*c
    'asdfa'
    1+2+3+4
    return a+b
func(2,2,2)
# Out:
# 4

# %%
def func(a,b):
    a=10
    b=10

    return a+b
func(2,2)
# Out:
# 20

# %%
a=3
b=4

def func(a,b):  #a=2 내부적으로 실행행
    a=10         #b=2
    b=10

    return a+b
c=func(2,2)
a
# Out:
# 3

# %%
a=10
b=20
def func():

    a=30
func()
a
# Out:
# 10

# %%
a=10
b=20
def func():
    global a
    a=30
func()
a
# Out:
# 30

# %%
def add(a,b):
    return a+b
func  =add
func(3,4)
# Out:
# 7

# %%
def add(a,b):
    return a+b

add(3,4)
# Out:
# 7

# %%
add =(lambda a,b:a+b)
func=add
func(3,4)
# Out:
# 7

# %%
a=[1,2,3,4]
b=[] #3,5,7,9

b=list(map(lambda x : x*2+1,a))
b  #람다 -함수 이름 없이 사용
# Out:
# [3, 5, 7, 9]

# %%
#파라미터 (매개변수)이용한 함수
def func(a,b,c,d,e,f):
    return a+b#c/d-e**f
func(a=1,b=2,c=3,d=5,e=6,f=4,)  #순서대로 -포지셔닝 아규먼트 ,불규칙: 키워드 아규먼트트
# Out:
# 3

# %%
def func(a,b,c,d,e,f):
    return a+b*c/d-e**f
func(1,2,3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-fea6ab3664f3> in <cell line: 3>()
#       1 def func(a,b,c,d,e,f):
#       2     return a+b * c/d-e**f
# ----> 3 func(1,2,3,4)
#
# TypeError: func() missing 2 required positional arguments: 'e' and 'f'
